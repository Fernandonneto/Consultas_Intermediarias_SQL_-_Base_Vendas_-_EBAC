# %% [markdown]
# # **MÓDULO 25 - Operações Básicas SQL**

# %% [markdown]
# Para nossa atividade inicial de SQL trabalharemos com uma base de vendas.
# Abaixo temos o ambiente de preparo para trabalharmos com o SQL lite.

# %%
import sqlite3 #Importando a biblioteca necessária
import pandas as pd

# %%
df_vendas = pd.read_csv("TB_VENDAS_TAREFA.csv", delimiter=';', decimal=',')

# %%
conn = sqlite3.connect(':memory:')
df_vendas.to_sql('tb_vendas', conn, index=False, if_exists='replace')
# Out:
# 24

# %%
def run_query(query):
    return pd.read_sql_query(query, conn)

# %% [markdown]
# # 1) Faça uma consulta que retorne os nomes dos produtos distintos que temos na base de venda.

# %% [markdown]
# Interpretação
#
# Colunas: Produtos
#
# Operações: Não
#
# Filtros: Não
#
# Agrupamento: Não
#
# Ordenação: Não
#
# Distintos: Sim
#
# Origem: tb_vendas

# %%
query = """
SELECT DISTINCT PRODUTO
FROM tb_vendas
"""
result_df = run_query(query)
print(result_df)
# Out:
#     PRODUTO
# 0  CAMISETA
# 1     CALCA
# 2   BERMUDA
# 3   VESTIDO
# 4      MEIA

# %% [markdown]
# # 2) Faça uma consulta que retorne a contagem dos clientes distintos que temos na nossa base, não esqueça de renomear sua coluna.
#
# Dica: Você pode usar o distinct dentro do count()

# %% [markdown]
# Interpretação
#
# Colunas: Clientes
#
# Operações: Sim (COUNT)
#
# Filtros: Não
#
# Agrupamento: Não
#
# Ordenação: Não
#
# Distintos: Sim
#
# Origem: tb_vendas

# %%
query = """
SELECT COUNT(DISTINCT ID_CLIENTE)
AS QNT_CLIENTES_DISTINTOS
FROM tb_vendas
"""
result_df = run_query(query)
print(result_df)
# Out:
#    QNT_CLIENTES_DISTINTOS
# 0                      22

# %% [markdown]
# # 3) Faça uma consulta que retorne uma coluna com os produtos distintos e o valor_unid de cada produto. Porém apenas para produtos onde o valor_unid é maior ou igual a 50 reais.

# %% [markdown]
# Interpretação
#
# Colunas: Produtos e valor da unidade
#
# Operações: Não
#
# Filtros: Sim
#
# Agrupamento: Não
#
# Ordenação: Não
#
# Distintos: Sim
#
# Origem: tb_vendas

# %%
query = """
SELECT DISTINCT PRODUTO, VALOR_UNID
FROM tb_vendas
WHERE VALOR_UNID >= 50
"""
result_df = run_query(query)
print(result_df)
# Out:
#    PRODUTO  VALOR_UNID
# 0    CALCA        89.9
# 1  BERMUDA        79.5
# 2  VESTIDO       102.0

# %% [markdown]
# # [DESAFIO] 4) Faça uma consulta que retorne o ID das compras e o valor total gasto nessa compra (Valor_unidade X Unidades) das 5 compras com mais valor total gasto.

# %% [markdown]
# Interpretação
#
# Colunas: ID das compras e o valor total gasto
#
# Operações: Sim (*)
#
# Filtros: Não
#
# Agrupamento: Não
#
# Ordenação: Sim (DESC)
#
# Distintos: Não
#
# Limites: Sim (5)
#
# Origem: tb_vendas

# %%
query = """
SELECT ID_COMPRA, VALOR_UNID * UNIDADES
AS VALOR_TOTAL
FROM tb_vendas
ORDER BY VALOR_TOTAL DESC
LIMIT 5
"""
result_df = run_query(query)
print(result_df)
# Out:
#    ID_COMPRA  VALOR_TOTAL
# 0       1267        204.0
# 1       1253        179.8
# 2       1255        179.8
# 3       1257        179.8
# 4       1262        179.8

# %% [markdown]
# # 5) Faça uma consulta que retorne os produtos e a média do preço da unidade dos produtos, ordenando do maior para o menor.

# %% [markdown]
# Interpretação
#
# Colunas: Produtos e média do preço da unidade
#
# Operações: Sim (AVG)
#
# Filtros: Não
#
# Agrupamento: Sim
#
# Ordenação: Sim (DESC)
#
# Distintos: Não
#
# Limites: Não
#
# Origem: tb_vendas

# %%
query = """
SELECT PRODUTO, AVG(VALOR_UNID)
AS MEDIA_PRECO
FROM tb_vendas
GROUP BY PRODUTO
ORDER BY MEDIA_PRECO DESC
"""
result_df = run_query(query)
print(result_df)
# Out:
#     PRODUTO  MEDIA_PRECO
# 0   VESTIDO        102.0
# 1     CALCA         89.9
# 2   BERMUDA         79.5
# 3  CAMISETA         34.5
# 4      MEIA         25.9

# %% [markdown]
# # 6) Faça uma consulta que retorne o id dos 3 clientes da base de vendas que mais relalizaram compras e a quantidade de compras realizadas.

# %% [markdown]
# Interpretação
#
# Colunas: Id clientes e quantidade de compras realizadas
#
# Operações: Sim (SUM)
#
# Filtros: Não
#
# Agrupamento: Sim
#
# Ordenação: Sim (DESC)
#
# Distintos: Não
#
# Limites: Sim (3)
#
# Origem: tb_vendas

# %%
query = """
SELECT ID_CLIENTE, SUM(UNIDADES)
AS QNT_COMPRAS
FROM tb_vendas
GROUP BY ID_CLIENTE
ORDER BY QNT_COMPRAS DESC
LIMIT 3
"""
result_df = run_query(query)
print(result_df)
# Out:
#    ID_CLIENTE  QNT_COMPRAS
# 0        9796            4
# 1        9425            4
# 2        9799            3
